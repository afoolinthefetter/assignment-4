# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
import tensorflow as tf
import datetime
# Clear any logs from previous runs
# !rm -rf ./logs/

# %% [markdown]
# # 1 Block VGG Model

# %%
# baseline model for the dogs vs cats dataset
import sys
from matplotlib import pyplot
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
	return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    pyplot.subplot(211)
    pyplot.title('Cross Entropy Loss')
    pyplot.plot(history.history['loss'], color='blue', label='train')
    pyplot.plot(history.history['val_loss'], color='orange', label='test')
    pyplot.legend(['train', 'test'])
    # plot accuracy
    pyplot.subplot(212)
    pyplot.title('Classification Accuracy')
    pyplot.plot(history.history['accuracy'], color='blue', label='train')
    pyplot.plot(history.history['val_accuracy'], color='orange', label='test')
    pyplot.legend(['train', 'test'])
    # show the plot
    pyplot.show()

# run the test harness for evaluating a model
def run_test_harness():
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(rescale=1.0/255.0)
	# prepare iterators
	train_it = datagen.flow_from_directory('/content/drive/MyDrive/train/',
		class_mode='binary', batch_size=64, target_size=(200, 200))
	test_it = datagen.flow_from_directory('/content/drive/MyDrive/test/',
		class_mode='binary', batch_size=64, target_size=(200, 200))

	log_dir = "logs/fit/" + "1_block"
	tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, update_freq="batch")
	# fit model
	# history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
	# 	validation_data=test_it, validation_steps=len(test_it), epochs=20, verbose=0)
	history = model.fit(train_it, validation_data=test_it, epochs=10,batch_size=32, verbose=0, callbacks=[tensorboard_callback])
	# evaluate model
	_, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
# !zip /content/logs.zip -r /content/logs
# Out:
#   adding: content/logs/ (stored 0%)
#   adding: content/logs/fit/ (stored 0%)
#   adding: content/logs/fit/1_block/ (stored 0%)
#   adding: content/logs/fit/1_block/train/ (stored 0%)
#   adding: content/logs/fit/1_block/train/events.out.tfevents.1713169279.0f8c97fe6784.3049.0.v2 (deflated 67%)
#   adding: content/logs/fit/1_block/validation/ (stored 0%)
#   adding: content/logs/fit/1_block/validation/events.out.tfevents.1713169285.0f8c97fe6784.3049.1.v2 (deflated 54%)

# %% [markdown]
# # 2 Block VGG Model

# %%
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(1, activation='sigmoid'))
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
	return model

def run_test_harness():
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(rescale=1.0/255.0)
	# prepare iterators
	train_it = datagen.flow_from_directory('/content/drive/MyDrive/train/',
		class_mode='binary', batch_size=64, target_size=(200, 200))
	test_it = datagen.flow_from_directory('/content/drive/MyDrive/test/',
		class_mode='binary', batch_size=64, target_size=(200, 200))
	# fit model
	history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=test_it, validation_steps=len(test_it), epochs=20, verbose=0)
	# evaluate model
	_, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# <ipython-input-4-c269db9b2391>:25: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# <ipython-input-4-c269db9b2391>:28: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
# > 87.500

# %%
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200, 200, 3)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
	return model

def run_test_harness():
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(rescale=1.0/255.0)
	# prepare iterators
	train_it = datagen.flow_from_directory('/content/drive/MyDrive/train/',
		class_mode='binary', batch_size=64, target_size=(200, 200))
	test_it = datagen.flow_from_directory('/content/drive/MyDrive/test/',
		class_mode='binary', batch_size=64, target_size=(200, 200))
	# fit model
	history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=test_it, validation_steps=len(test_it), epochs=20, verbose=0)
	# evaluate model
	_, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# <ipython-input-5-45c6e266d5a8>:29: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# <ipython-input-5-45c6e266d5a8>:32: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
# > 85.000

# %% [markdown]
# # Regularization with Data Augmentation

# %%
def run_test_harness():
 # define model
 model = define_model()
 # create data generators
 train_datagen = ImageDataGenerator(rescale=1.0/255.0,
 width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
 test_datagen = ImageDataGenerator(rescale=1.0/255.0)
 # prepare iterators
 train_it = train_datagen.flow_from_directory('/content/drive/MyDrive/train/',
 class_mode='binary', batch_size=64, target_size=(200, 200))
 test_it = test_datagen.flow_from_directory('/content/drive/MyDrive/test/',
 class_mode='binary', batch_size=64, target_size=(200, 200))
 # fit model
 history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
 validation_data=test_it, validation_steps=len(test_it), epochs=50, verbose=0)
 # evaluate model
 _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
 print('> %.3f' % (acc * 100.0))
 # learning curves
 summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# <ipython-input-6-06ef921f4e62>:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# <ipython-input-6-06ef921f4e62>:17: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
# > 80.000

# %%
from keras.models import Model
from keras.applications.vgg16 import VGG16
# define cnn model
def define_model():
	# load model
	model = VGG16(include_top=False, input_shape=(224, 224, 3))
	# mark loaded layers as not trainable
	for layer in model.layers:
		layer.trainable = False
	# add new classifier layers
	flat1 = Flatten()(model.layers[-1].output)
	class1 = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat1)
	output = Dense(1, activation='sigmoid')(class1)
	# define new model
	model = Model(inputs=model.inputs, outputs=output)
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
	return model


# run the test harness for evaluating a model
def run_test_harness():
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(featurewise_center=True)
	# specify imagenet mean values for centering
	datagen.mean = [123.68, 116.779, 103.939]
	# prepare iterator
	train_it = datagen.flow_from_directory('/content/drive/MyDrive/train/',
		class_mode='binary', batch_size=64, target_size=(224, 224))
	test_it = datagen.flow_from_directory('/content/drive/MyDrive/test/',
		class_mode='binary', batch_size=64, target_size=(224, 224))
	# fit model
	history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=test_it, validation_steps=len(test_it), epochs=10, verbose=1)
	# evaluate model
	_, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# <ipython-input-7-bffd6c14acb6>:36: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# Epoch 1/10
# 3/3 [==============================] - 31s 9s/step - loss: 74.9012 - accuracy: 0.5500 - val_loss: 370.0732 - val_accuracy: 0.5000
# Epoch 2/10
# 3/3 [==============================] - 1s 580ms/step - loss: 298.7599 - accuracy: 0.7875 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/10
# 3/3 [==============================] - 1s 448ms/step - loss: 87.9508 - accuracy: 0.9812 - val_loss: 686.6595 - val_accuracy: 0.9000
# Epoch 4/10
# 3/3 [==============================] - 2s 626ms/step - loss: 251.7077 - accuracy: 0.9500 - val_loss: 79.4324 - val_accuracy: 0.9750
# Epoch 5/10
# 3/3 [==============================] - 2s 471ms/step - loss: 12.8691 - accuracy: 0.9875 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/10
# 3/3 [==============================] - 2s 627ms/step - loss: 391.2115 - accuracy: 0.9875 - val_loss: 470.7603 - val_accuracy: 0.9750
# Epoch 7/10
# 3/3 [==============================] - 2s 470ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 989.9816 - val_accuracy: 0.9500
# Epoch 8/10
# 3/3 [==============================] - 2s 639ms/step - loss: 78.7364 - accuracy: 0.9812 - val_loss: 902.8960 - val_accuracy: 0.9750
# Epoch 9/10
# 3/3 [==============================] - 1s 443ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 10/10
# 3/3 [==============================] - 1s 436ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# <ipython-input-7-bffd6c14acb6>:39: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
# > 100.000

# %% [markdown]
# #

# %%
from keras.models import Model
from keras.applications.vgg16 import VGG16
# define cnn model
def define_model():
	# load model
	model = VGG16(include_top=False, input_shape=(224, 224, 3))
	# mark loaded layers as not trainable
	for layer in model.layers:
		layer.trainable = True
	# add new classifier layers
	flat1 = Flatten()(model.layers[-1].output)
	class1 = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat1)
	output = Dense(1, activation='sigmoid')(class1)
	# define new model
	model = Model(inputs=model.inputs, outputs=output)
	# compile model
	opt = SGD(lr=0.001, momentum=0.9)
	model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
	return model


# run the test harness for evaluating a model
def run_test_harness():
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(featurewise_center=True)
	# specify imagenet mean values for centering
	datagen.mean = [123.68, 116.779, 103.939]
	# prepare iterator
	train_it = datagen.flow_from_directory('/content/drive/MyDrive/train/',
		class_mode='binary', batch_size=64, target_size=(224, 224))
	test_it = datagen.flow_from_directory('/content/drive/MyDrive/test/',
		class_mode='binary', batch_size=64, target_size=(224, 224))
	# fit model
	history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
		validation_data=test_it, validation_steps=len(test_it), epochs=10, verbose=1)
	# evaluate model
	_, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# entry point, run the test harness
run_test_harness()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# <ipython-input-8-63f08ae0e4da>:36: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_it, steps_per_epoch=len(train_it),
# Epoch 1/10
# 3/3 [==============================] - 46s 7s/step - loss: 27.4794 - accuracy: 0.5312 - val_loss: 287.1531 - val_accuracy: 0.5000
# Epoch 2/10
# 3/3 [==============================] - 3s 842ms/step - loss: 116.4317 - accuracy: 0.5625 - val_loss: 1.3332 - val_accuracy: 0.5750
# Epoch 3/10
# 3/3 [==============================] - 3s 783ms/step - loss: 4.8117 - accuracy: 0.5000 - val_loss: 0.8242 - val_accuracy: 0.5000
# Epoch 4/10
# 3/3 [==============================] - 3s 779ms/step - loss: 0.7882 - accuracy: 0.5000 - val_loss: 0.8468 - val_accuracy: 0.4750
# Epoch 5/10
# 3/3 [==============================] - 3s 814ms/step - loss: 1.2561 - accuracy: 0.4875 - val_loss: 0.7715 - val_accuracy: 0.4250
# Epoch 6/10
# 3/3 [==============================] - 3s 780ms/step - loss: 0.7224 - accuracy: 0.4625 - val_loss: 0.7366 - val_accuracy: 0.4500
# Epoch 7/10
# 3/3 [==============================] - 3s 765ms/step - loss: 0.6780 - accuracy: 0.6187 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 8/10
# 3/3 [==============================] - 3s 771ms/step - loss: 0.6694 - accuracy: 0.5312 - val_loss: 0.7272 - val_accuracy: 0.5000
# Epoch 9/10
# 3/3 [==============================] - 3s 918ms/step - loss: 0.6709 - accuracy: 0.5813 - val_loss: 0.6735 - val_accuracy: 0.5500
# Epoch 10/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.5910 - accuracy: 0.7312 - val_loss: 0.6132 - val_accuracy: 0.6500
# <ipython-input-8-63f08ae0e4da>:39: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   _, acc = model.evaluate_generator(test_it, steps=len(test_it), verbose=0)
# > 65.000

# %%
model = VGG16(include_top=False, input_shape=(224, 224, 3))
	# mark loaded layers as not trainable
for layer in model.layers:
  print(layer)
# Out:
# <keras.src.engine.input_layer.InputLayer object at 0x7d95eaef19c0>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95eaef0b20>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95eaef1e70>
# <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7d95ea6b3f10>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ea3665f0>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead29720>
# <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7d95eac2fb80>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ea6e20b0>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead28e50>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95eaef23e0>
# <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7d95ead74190>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead2a620>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead76950>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95eaef1360>
# <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7d95ead50cd0>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead2b9a0>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead52f20>
# <keras.src.layers.convolutional.conv2d.Conv2D object at 0x7d95ead2b190>
# <keras.src.layers.pooling.max_pooling2d.MaxPooling2D object at 0x7d95ead53640>
